# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport

# %%
df =pd.read_excel('./datasets/Lista Incendios_2015.xlsx')
#EDA using pandas-profiling
profile = ProfileReport(df, explorative=True)

#Saving results to a HTML file
profile.to_file("./output/output.html")
# Out:
# Summarize dataset: 100%|██████████| 153/153 [00:15<00:00,  9.66it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:04<00:00,  4.07s/it]
# Render HTML: 100%|██████████| 1/1 [00:02<00:00,  2.33s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 105.33it/s]

# %%
# Checking head
df.head()
# Out:
#     Ano Codigo SGIF    Codigo_ANPC          Tipo          Distrito  \
# 0  2015    DM315252  2015160007544     Florestal  Viana do Castelo
# 1  2015    DM215305  2015130043758     Florestal             Porto
# 2  2015    DM415293  2015030021973     Florestal             Braga
# 3  2015    DM315261  2015160007563  Falso Alarme  Viana do Castelo
# 4  2015    BL115321  2015180015874      Agrícola             Viseu
#
#              Concelho           Freguesia                            Local  \
# 0       Ponte de Lima           Serdedelo      VALE DE TROVELA (SERDEDELO)
# 1  Marco de Canaveses  Vila Boa de Quires                    LUGAR DO FOFO
# 2          Vila Verde                Lage            RUA PROF ABEL MADEIRA
# 3       Ponte de Lima            Boalhosa  J. DEPOSITOS DE AGUA (BOALHOSA)
# 4        Castro Daire        Castro Daire      Farejinhas - Bº das Queirós
#
#       INE       x  ...  Falso Alarme Fogacho Incendio Agricola Perimetro  APS  \
# 0  160746  167814  ...             0       0        1        0       NaN  NaN
# 1  130731  193731  ...             0       0        1        0       NaN  NaN
# 2   31323  172162  ...             0       1        0        0       NaN  NaN
# 3  160709  171291  ...             1       0        0        0       NaN  NaN
# 4  180304  217299  ...             0       1        0        0       NaN  NaN
#
#    Causa     TipoCausa          Região PROF          UGF
# 0  122.0    Negligente  Entre Douro e Minho   Alto Minho
# 1  122.0    Negligente  Entre Douro e Minho       Tâmega
# 2   60.0  Desconhecida  Entre Douro e Minho  Baixo Minho
# 3  630.0  Desconhecida  Entre Douro e Minho   Alto Minho
# 4  630.0  Desconhecida        Beira Litoral   Dão Lafões
#
# [5 rows x 38 columns]

# %%
#checking tail
df.tail()
# Out:
#         Ano Codigo SGIF    Codigo_ANPC          Tipo Distrito  \
# 23170  2015   DM4151671  2015030056919     Florestal    Braga
# 23171  2015   BL1151018  2015180041997     Florestal    Viseu
# 23172  2015   BL3151227  2015010055691  Falso Alarme   Aveiro
# 23173  2015   DM2153226  2015130115988     Florestal    Porto
# 23174  2015   BL3151229  2015010055723  Falso Alarme   Aveiro
#
#                    Concelho          Freguesia                   Local  \
# 23170                  Fafe               Fafe          RUA DE FORNELO
# 23171               Cinfães            Cinfães               Ventuzela
# 23172  Santa Maria da Feira              Feira     avenida 25 de abril
# 23173     Paços de Ferreira  Paços de Ferreira  Lugar alto das Cavadas
# 23174  Santa Maria da Feira           Rio Meão         Casais de Baixo
#
#           INE       x  ...  Falso Alarme Fogacho Incendio Agricola Perimetro  \
# 23170   30709  196478  ...             0       1        0        0       NaN
# 23171  180403  203110  ...             0       0        1        0       NaN
# 23172   10906  164395  ...             1       0        0        0       NaN
# 23173  130912  180666  ...             0       1        0        0       NaN
# 23174   10921  161792  ...             1       0        0        0       NaN
#
#        APS  Causa      TipoCausa          Região PROF  \
# 23170  NaN   60.0   Desconhecida  Entre Douro e Minho
# 23171  NaN  125.0     Negligente  Entre Douro e Minho
# 23172  NaN    NaN            NaN  Entre Douro e Minho
# 23173  NaN  711.0  Reacendimento  Entre Douro e Minho
# 23174  NaN    NaN            NaN  Entre Douro e Minho
#
#                              UGF
# 23170                Baixo Minho
# 23171                     Tâmega
# 23172  AMP e Entre Douro e Vouga
# 23173                     Tâmega
# 23174  AMP e Entre Douro e Vouga
#
# [5 rows x 38 columns]

# %%
# checking shape 
print('Number of Rows: ', df.shape[0])
print('Number of Columns: ',df.shape[1])
# Out:
# Number of Rows:  23175
# Number of Columns:  38

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23175 entries, 0 to 23174
# Data columns (total 38 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Ano                                  23175 non-null  int64
#  1   Codigo SGIF                          23175 non-null  object
#  2   Codigo_ANPC                          23175 non-null  int64
#  3   Tipo                                 23175 non-null  object
#  4   Distrito                             23175 non-null  object
#  5   Concelho                             23175 non-null  object
#  6   Freguesia                            23175 non-null  object
#  7   Local                                23174 non-null  object
#  8   INE                                  23175 non-null  int64
#  9   x                                    23175 non-null  int64
#  10  y                                    23175 non-null  int64
#  11  lat                                  23175 non-null  object
#  12  lon                                  23175 non-null  object
#  13  DataAlerta                           23175 non-null  object
#  14  HoraAlerta                           23175 non-null  object
#  15  DataExtincao                         22863 non-null  object
#  16  HoraExtincao                         22858 non-null  object
#  17  Data1Intervencao                     21976 non-null  object
#  18  Hora1Intervencao                     21962 non-null  object
#  19  FonteAlerta                          0 non-null      float64
#  20  NUT                                  23175 non-null  object
#  21  AA_Povoamento (ha)                   23175 non-null  float64
#  22  AA_Mato (ha)                         23175 non-null  float64
#  23  AA_Agricola (ha)                     23175 non-null  float64
#  24  AA_EspacosFlorestais (pov+mato)(ha)  23175 non-null  float64
#  25  AA_Total (pov+mato+agric) (ha)       23175 non-null  float64
#  26  Reacendimentos                       23175 non-null  int64
#  27  Queimada                             23175 non-null  int64
#  28  Falso Alarme                         23175 non-null  int64
#  29  Fogacho                              23175 non-null  int64
#  30  Incendio                             23175 non-null  int64
#  31  Agricola                             23175 non-null  int64
#  32  Perimetro                            826 non-null    object
#  33  APS                                  1059 non-null   object
#  34  Causa                                16162 non-null  float64
#  35  TipoCausa                            16162 non-null  object
#  36  Região PROF                          23173 non-null  object
#  37  UGF                                  23174 non-null  object
# dtypes: float64(7), int64(11), object(20)
# memory usage: 6.7+ MB

# %%
df.columns
# Out:
# Index(['Ano', 'Codigo SGIF', 'Codigo_ANPC', 'Tipo', 'Distrito', 'Concelho',
#        'Freguesia', 'Local', 'INE', 'x', 'y', 'lat', 'lon', 'DataAlerta',
#        'HoraAlerta', 'DataExtincao', 'HoraExtincao', 'Data1Intervencao',
#        'Hora1Intervencao', 'FonteAlerta', 'NUT', 'AA_Povoamento (ha)',
#        'AA_Mato (ha)', 'AA_Agricola (ha)',
#        'AA_EspacosFlorestais (pov+mato)(ha)', 'AA_Total (pov+mato+agric) (ha)',
#        'Reacendimentos', 'Queimada', 'Falso Alarme', 'Fogacho', 'Incendio',
#        'Agricola', 'Perimetro', 'APS', 'Causa', 'TipoCausa', 'Região PROF',
#        'UGF'],
#       dtype='object')

# %%
df.groupby('Tipo')['Ano'].count()
# Out:
# Tipo
# Agrícola         4163
# Falso Alarme     2925
# Florestal       15464
# Queimada          623
# Name: Ano, dtype: int64

# %%
df.groupby('TipoCausa')['Ano'].count()
# Out:
# TipoCausa
# Desconhecida     5433
# Intencional      3086
# Natural           150
# Negligente       5957
# Reacendimento    1536
# Name: Ano, dtype: int64

# %%
df.groupby('Distrito')['Ano'].count()
# Out:
# Distrito
# Aveiro              1774
# Beja                 438
# Braga               2231
# Bragança             733
# Castelo Branco       544
# Coimbra              749
# Faro                 584
# Guarda               809
# Leiria               906
# Lisboa              2225
# Portalegre           363
# Porto               4444
# Santarém            1328
# Setúbal             1173
# Viana Do Castelo      76
# Viana do Castelo    1483
# Vila Real           1481
# Viseu               1528
# Évora                306
# Name: Ano, dtype: int64
